# %%
import pandas as pd 
import numpy as np 
import json 
import tweepy
import os 
import requests
from timeit import default_timer as timer

# %%
# Generate your own at https://apps.twitter.com/app
CONSUMER_KEY = '######'
CONSUMER_SECRET = '#####'
OAUTH_TOKEN = '##-#'
OAUTH_TOKEN_SECRET = '##'

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
try:
    redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
    print('Error! Failed to get request token.')

# %% [markdown]
# ###  Gathering the data from twitter api to save it in tweet_json text file

# %%
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Success
# 2: 892177421306343426
# Success
# 3: 891815181378084864
# Success
# 4: 891689557279858688
# Success
# 5: 891327558926688256
# Success
# 6: 891087950875897856
# Success
# 7: 890971913173991426
# Success
# 8: 890729181411237888
# Success
# 9: 890609185150312448
# Success
# 10: 890240255349198849
# Success
# 11: 890006608113172480
# Success
# 12: 889880896479866881
# Success
# 13: 889665388333682689
# Success
# 14: 889638837579907072
# Success
# 15: 889531135344209921
# Success
# 16: 889278841981685760
# Success
# 17: 888917238123831296
# Success
# 18: 888804989199671297
# Success
# 19: 888554962724278272
# Success
# 20: 888202515573088257
# Fail
# 21: 888078434458587136
# Success
# 22: 887705289381826560
# Success
# 23: 887517139158093824
# Success
# 24: 887473957103951883
# Success
# 25: 887343217045368832
# Success
# 26: 887101392804085760
# Success
# 27: 886983233522544640
# Success
# 28: 886736880519319552
# Success
# 29: 886680336477933568
# ...

# %% [markdown]
# ### Reading the data inside the given enhanched twitter archive in a dataframe

# %%
df = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# ### Visual assessment for df

# %%
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ### Programming assessment for df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
#df[df['rating_denominator']==170].expanded_urls

# %% [markdown]
# > here is a problem that the rating denominator isn't 10 like the rest of dataframe, also by checking the expanded urls the link isn't working

# %%
df.doggo.value_counts()
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
df.floofer.value_counts()
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
df.pupper.value_counts()
# Out:
# None      2099
# pupper     257
# Name: pupper, dtype: int64

# %%
df.puppo.value_counts()
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
pd.options.display.max_colwidth = 200

# %%
df.source.unique()
# Out:
# array([ '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'], dtype=object)

# %% [markdown]
# ## we need to make a column for the variable of the source but filter the important one only

# %%
df[df['tweet_id']==891815181378084864].text
# Out:
# 2    This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# Name: text, dtype: object

# %%
df.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2118  670420569653809152                    NaN                  NaN
# 478   815966073409433600                    NaN                  NaN
# 935   753398408988139520                    NaN                  NaN
# 2198  668815180734689280                    NaN                  NaN
# 448   819006400881917954                    NaN                  NaN
#
#                       timestamp  \
# 2118  2015-11-28 01:54:54 +0000
# 478   2017-01-02 17:00:46 +0000
# 935   2016-07-14 01:19:12 +0000
# 2198  2015-11-23 15:35:39 +0000
# 448   2017-01-11 02:21:57 +0000
#
#                                                                                   source  \
# 2118  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 478   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# columns like retweeted_status_id , retweeted_status_user_id , retweeted_status_timestamp are full of NaNs

# %%
#df.in_reply_to_status_id.unique()

# %%
#df.retweeted_status_user_id.unique()

# %%
#df.retweeted_status_timestamp.unique()

# %%
df.name.value_counts()
# Out:
# None          745
# a              55
# Charlie        12
# Lucy           11
# Oliver         11
# Cooper         11
# Lola           10
# Penny          10
# Tucker         10
# Bo              9
# Winston         9
# Sadie           8
# the             8
# Buddy           7
# Bailey          7
# Daisy           7
# an              7
# Toby            7
# Bella           6
# Leo             6
# Jax             6
# Oscar           6
# Dave            6
# Koda            6
# Milo            6
# Scout           6
# Stanley         6
# Rusty           6
# Jack            6
# Phil            5
#              ...
# Darby           1
# Bones           1
# Grizzie         1
# Herb            1
# Maxwell         1
# Stu             1
# Mollie          1
# Chloe           1
# Tuck            1
# Kawhi           1
# space           1
# Clyde           1
# Stuart          1
# Joey            1
# Dobby           1
# Kaia            1
# Andy            1
# Ricky           1
# Zeus            1
# ...

# %%
df[df['name']=='a']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 56    881536004380872706                    NaN                  NaN
# 649   792913359805018113                    NaN                  NaN
# 801   772581559778025472                    NaN                  NaN
# 1002  747885874273214464                    NaN                  NaN
# 1004  747816857231626240                    NaN                  NaN
# 1017  746872823977771008                    NaN                  NaN
# 1049  743222593470234624                    NaN                  NaN
# 1193  717537687239008257                    NaN                  NaN
# 1207  715733265223708672                    NaN                  NaN
# 1340  704859558691414016                    NaN                  NaN
# 1351  704054845121142784                    NaN                  NaN
# 1361  703079050210877440                    NaN                  NaN
# 1368  702539513671897089                    NaN                  NaN
# ...

# %%
#df.expanded_urls

# %%
df.retweeted_status_user_id.nunique()
# Out:
# 25

# %% [markdown]
# ## checking if there is a duplicated tweets_ids in our dataframe

# %%
df.tweet_id.duplicated().sum()
# Out:
# 0

# %%
#df.retweeted_status_id.unique()

# %% [markdown]
# ### Assessing the values of the numerator, the denominator values

# %%
df.rating_numerator.unique()
# Out:
# array([  13,   12,   14,    5,   17,   11,   10,  420,  666,    6,   15,
#         182,  960,    0,   75,    7,   84,    9,   24,    8,    1,   27,
#           3,    4,  165, 1776,  204,   50,   99,   80,   45,   60,   44,
#         143,  121,   20,   26,    2,  144,   88])

# %%
df.rating_denominator.unique()
# Out:
# array([ 10,   0,  15,  70,   7,  11, 150, 170,  20,  50,  90,  80,  40,
#        130, 110,  16, 120,   2])

# %% [markdown]
# ## Quality for df
#
# * None value that are placd in the floofer , pupper , puppo , etc need to be replaced by Null
# * we need to limit the time stamp to be before 1 august 2017
# * we need to convert timestamp column to datetime variable
# * 745 dogs has a None as a value in the column, no reason that a dog can have a name called (None)
# * 55  dogs has a a as a value in the column, no reason that a dog can have a name called (a)
# * columns like in reply to user id and in reply to status id has many null objects so need to drop these columns
# * drop the columns of the retweeted status id as we are interested in the original tweets not the retweeted
# * there are values where the denonmirator is zero and that can't be true as you can't divide by zero
# * the entry or the record where the column of rating denominator of 170 must be deleted
#
# ## TIDNESS for df
# * there is 4 columns for one variable which is dog type ( pupper , puppo, floofer)
# * no need for the column rating_ denominator as it is always 10

# %% [markdown]
# ## Gathering the data for image predictions that is provided by udacity in a url

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'

# %%
response = requests.get(url)
    #with open (os.path.join(folder_name,x.split('/')[-1]),mode='wb') as file:
     #   file.write(response.content)

# %%
with open ('image-predictions',mode='wb') as file:
       file.write(response.content)

# %%
df2 = pd.read_csv('image-predictions', sep='\t')

# %% [markdown]
# ### making visual assessment for df2

# %%
df2.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
df2.sample(5)
# Out:
#                 tweet_id  \
# 615   680176173301628928
# 1865  843235543001513987
# 827   693486665285931008
# 981   707377100785885184
# 641   681320187870711809
#
#                                                                                       jpg_url  \
# 615                                           https://pbs.twimg.com/media/CXB4nWnWEAAhLTX.jpg
# 1865                                          https://pbs.twimg.com/media/C7PGQJAWwAAibui.jpg
# 827   https://pbs.twimg.com/ext_tw_video_thumb/693486485266247680/pu/img/KhapmUYPQTpbwNf8.jpg
# 981                                           https://pbs.twimg.com/media/CdEbt0NXIAQH3Aa.jpg
# 641                                           https://pbs.twimg.com/media/CXSJGAQUQAAoG9Q.jpg
#
#       img_num                  p1   p1_conf  p1_dog           p2   p2_conf  \
# 615         1  Christmas_stocking  0.207547   False         mask  0.193880
# 1865        1            Pembroke  0.958452    True     Cardigan  0.023770
# ...

# %%
df2[df2['tweet_id']==666020888022790149].jpg_url
# Out:
# 0    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# Name: jpg_url, dtype: object

# %%
df[df['tweet_id']==666020888022790149].expanded_urls
# Out:
# 2355    https://twitter.com/dog_rates/status/666020888022790149/photo/1
# Name: expanded_urls, dtype: object

# %%
df2.img_num.value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %% [markdown]
# ### making programming assessment for df2

# %%
df2.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
#df2['total']=df2['p1_conf']+df2['p2_conf']+df2['p3_conf']

# %% [markdown]
# ## Checking the photos that any of the 3 algorithms say it is a dog

# %%
x = df2.query("p3_dog==True | p1_dog==True | p2_dog==True")
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1751 entries, 0 to 2073
# Data columns (total 12 columns):
# tweet_id    1751 non-null int64
# jpg_url     1751 non-null object
# img_num     1751 non-null int64
# p1          1751 non-null object
# p1_conf     1751 non-null float64
# p1_dog      1751 non-null bool
# p2          1751 non-null object
# p2_conf     1751 non-null float64
# p2_dog      1751 non-null bool
# p3          1751 non-null object
# p3_conf     1751 non-null float64
# p3_dog      1751 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 141.9+ KB

# %% [markdown]
# > it is clear that only 1751 tweets is to be containing a photo of a dog according to the 3 algorithms

# %% [markdown]
# ## check if there is a duplicated tweet ids in our data

# %%
df2.tweet_id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### checking if the image num has values that aren't logical

# %%
df2.img_num.unique()
# Out:
# array([1, 4, 2, 3])

# %%
df2.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
#df2.p3_conf.value_counts()

# %% [markdown]
# ## Quality for df2
# * not all the image predicitions are for dogs p1 dogs,p2 dogs , p3 dogs must one of them true ( we need to be sure that one of the 3 columns containing true, if there is a label where all these values not true that means the photo isn't for a dog
# * there is no column to take decision saying that the most probable is the photo is a type of that dog
# * total column is ambiguous why it can't sum to be 1
# ### Tidness for df2
# * the jpg_url isn't the same url as the expanded url in df1, one opens the photo of the dog and the other opens the photo of the dog giving the status and the tweet in twitter
# * need to remove the entries or records that doesn't contain a photo of a dog according to the three algorithms

# %% [markdown]
# > after using twitter api for getting out data we have save them in a file now we will read this fil in a dataframe so we can work on it

# %%
with open('tweet_json.txt') as file:
    status = []
    for line in file:
        status.append(json.loads(line))

# %%
#status

# %%
#df3 = pd.DataFrame.from_dict(status,orient='columns')
#df3.reset_index(level=0, inplace=True)
#df3 = pd.DataFrame(status,orient='columns')
df3= pd.DataFrame.from_records(status)

# %%
pd.options.display.max_colwidth = 200

# %% [markdown]
#  ## visual assessing for the df3

# %%
df3.head()
# Out:
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Tue Aug 01 16:23:56 +0000 2017            [0, 85]
# 1         None        None  Tue Aug 01 00:17:27 +0000 2017           [0, 138]
# 2         None        None  Mon Jul 31 00:18:03 +0000 2017           [0, 121]
# 3         None        None  Sun Jul 30 15:58:51 +0000 2017            [0, 79]
# 4         None        None  Sat Jul 29 16:00:24 +0000 2017           [0, 138]
#
#                                                                                                                                                                                                   entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 892420639486877696, 'id_str': '892420639486877696', 'indices': [86, 109], 'media_url': 'http://pbs.twimg.com/media...
# ...

# %%
df3.sample(5)
# Out:
#      contributors coordinates                      created_at  \
# 324          None        None  Thu Feb 16 23:23:38 +0000 2017
# 799          None        None  Mon Aug 29 16:14:30 +0000 2016
# 445          None        None  Sat Jan 07 01:00:41 +0000 2017
# 1556         None        None  Wed Jan 13 04:23:58 +0000 2016
# 1803         None        None  Mon Dec 14 04:52:55 +0000 2015
#
#      display_text_range  \
# 324            [0, 112]
# 799             [0, 93]
# 445            [0, 143]
# 1556            [0, 74]
# 1803           [0, 137]
#
#                                                                                                                                                                                                      entities  \
# 324   {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 832369869089800192, 'id_str': '832369869089800192', 'indices': [113, 136], 'media_url': 'http://pbs.twimg.com/medi...
# ...

# %% [markdown]
# ## programming assessment for df3

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 32 columns):
# contributors                     0 non-null object
# coordinates                      0 non-null object
# created_at                       2331 non-null object
# display_text_range               2331 non-null object
# entities                         2331 non-null object
# extended_entities                2059 non-null object
# favorite_count                   2331 non-null int64
# favorited                        2331 non-null bool
# full_text                        2331 non-null object
# geo                              0 non-null object
# id                               2331 non-null int64
# id_str                           2331 non-null object
# in_reply_to_screen_name          77 non-null object
# in_reply_to_status_id            77 non-null float64
# in_reply_to_status_id_str        77 non-null object
# in_reply_to_user_id              77 non-null float64
# ...

# %%
df3.truncated.unique()
# Out:
# array([False], dtype=bool)

# %%
df3[df3['retweeted']==True]
# Out:
# Empty DataFrame
# Columns: [contributors, coordinates, created_at, display_text_range, entities, extended_entities, favorite_count, favorited, full_text, geo, id, id_str, in_reply_to_screen_name, in_reply_to_status_id, in_reply_to_status_id_str, in_reply_to_user_id, in_reply_to_user_id_str, is_quote_status, lang, place, possibly_sensitive, possibly_sensitive_appealable, quoted_status, quoted_status_id, quoted_status_id_str, quoted_status_permalink, retweet_count, retweeted, retweeted_status, source, truncated, user]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# > this shows that all the tweets aren't retweeted

# %%
df3.id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# > this shows that the tweet id are unique not duplicated

# %%
df3.retweeted.value_counts()
# Out:
# False    2331
# Name: retweeted, dtype: int64

# %%
df3.favorited.value_counts()
# Out:
# False    2331
# Name: favorited, dtype: int64

# %%
df3.retweeted_status.isnull().sum()
# Out:
# 2168

# %%
df3['source'].str.find('rel="nofollow">').unique()
# Out:
# array([45, 29, 25, 55])

# %%
df3.source.unique()
# Out:
# array([ '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'], dtype=object)

# %%
df3.possibly_sensitive.unique()
# Out:
# array([False, nan], dtype=object)

# %%
df3.possibly_sensitive_appealable.unique()
# Out:
# array([False, nan], dtype=object)

# %%
#x = []
#for i in df3['extended_entities'][0]['media']:
 #   x.append(i.values())

# %%
#df3['extended_entities']

# %%
#x = list(x)

# %%
#h = []
#for i, l in enumerate(df3["extended_entities"]):
 ##  print('/////')
   # h.append(l)
    #h1[0]['media'][0]['id']

# %%
#h1 = pd.DataFrame(h)
#h1 = list(h)
#h1[0]['media'][0]['id']

# %%
#h1[0]['media'][0]['id']

# %%
#z = []
#for x in h1:
 #   z.append(x[0]['media'][0]['id'])

# %%
#df3['extended_entities'][1]['media'].keys()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 32 columns):
# contributors                     0 non-null object
# coordinates                      0 non-null object
# created_at                       2331 non-null object
# display_text_range               2331 non-null object
# entities                         2331 non-null object
# extended_entities                2059 non-null object
# favorite_count                   2331 non-null int64
# favorited                        2331 non-null bool
# full_text                        2331 non-null object
# geo                              0 non-null object
# id                               2331 non-null int64
# id_str                           2331 non-null object
# in_reply_to_screen_name          77 non-null object
# in_reply_to_status_id            77 non-null float64
# in_reply_to_status_id_str        77 non-null object
# in_reply_to_user_id              77 non-null float64
# ...

# %%
df3.head()
# Out:
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Tue Aug 01 16:23:56 +0000 2017            [0, 85]
# 1         None        None  Tue Aug 01 00:17:27 +0000 2017           [0, 138]
# 2         None        None  Mon Jul 31 00:18:03 +0000 2017           [0, 121]
# 3         None        None  Sun Jul 30 15:58:51 +0000 2017            [0, 79]
# 4         None        None  Sat Jul 29 16:00:24 +0000 2017           [0, 138]
#
#                                                                                                                                                                                                   entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 892420639486877696, 'id_str': '892420639486877696', 'indices': [86, 109], 'media_url': 'http://pbs.twimg.com/media...
# ...

# %% [markdown]
# ## quality for df3
# * contributors column is all null
# * coordinates column is all null
# * place column contain only 1 non null so it isn't necessary
# * user column isnt adding any info as it is the same user
# * source column won't also add any extra info need to extract the source from it
# * no need for lang column as this obvious it is an english account
# ### tidness for df3
# * full text column dropped as we are going to join this dataframe with df1
# * columns sensitive and sensitive appeale ar false and nans so they should be deleted so no useful info
# * created at need to change to datetime type not object
# * display text range column need to be removed
# * entites column need to be removed
# * extended_entities column need to be removed
# * geo column isn't necessary
# * change the name of column (id) to (tweet_id) so that we have the same name of column for the same variable
# * change the typr of created at to be datetime type

# %% [markdown]
# ### Cleaning process for all the dataframes semgenting each
# ## Quality for df
#
# * None value that are placd in the floofer , pupper , puppo , etc need to be replaced by Null
# * we need to limit the time stamp to be before 1 august 2017
# * we need to convert timestamp column to datetime variable
# * 745 dogs has a None as a value in the column, no reason that a dog can have a name called (None)
# * 55  dogs has a a as a value in the column, no reason that a dog can have a name called (a)
# * columns like in reply to user id and in reply to status id has many null objects so need to drop these columns
# * drop the columns of the retweeted status id as we are interested in the original tweets not the retweeted
# * there are values where the denonmirator is zero and that can't be true as you can't divide by zero
# * the entry or the record where the column of rating denominator of 170 must be deleted
#
# ## TIDNESS for df
# * there is 4 columns for one variable which is dog type ( pupper , puppo, floofer)
# * no need for the column rating_ denominator as it is always 10
#
# ## Quality for df2
# * not all the image predicitions are for dogs p1 dogs,p2 dogs , p3 dogs must one of them true ( we need to be sure that one of the 3 columns containing true, if there is a label where all these values not true that means the photo isn't for a dog
# * there is no column to take decision saying that the most probable is the photo is a type of that dog
# * total column is ambiguous why it can't sum to be 1
# ## Tidness for df2
# * the jpg_url isn't the same url as the expanded url in df1, one opens the photo of the dog and thee other opens the photo of the dog giving the status and the tweet in twitter
# * need to remove the entries or records that doesn't contain a photo of a dog according to the three algorithms
#
# ## quality for df3
# * contributors column is all null
# * coordinates column is all null
# * place column contain only 1 non null so it isn't necessary
# * user column isnt adding any info as it is the same user
# * source column won't also add any extra info need to extract the source from it
# * no need for lang column as this obvious it is an english account
# ## tidness for df3
# * full text column dropped as we are going to join this dataframe with df1
# * columns sensitive and sensitive appeale ar false and nans so they should be deleted so no useful info
# * created at need to change to datetime type not object
# * display text range column need to be removed
# * entites column need to be removed
# * extended_entities column need to be removed
# * geo column isn't necessary
# * change the name of column (id) to (tweet_id) so that we have the same name of column for the same variable
# * change the typr of created at to be datetime type

# %% [markdown]
# ## Start of the cleaning process
# ### I will start with df

# %% [markdown]
# ## Quality for df
#
# * None value that are placd in the floofer , pupper , puppo , etc need to be replaced by Null
# * we need to limit the time stamp to be before 1 august 2017
# * we need to convert timestamp column to datetime variable
# * 745 dogs has a None as a value in the column, no reason that a dog can have a name called (None)
# * 55  dogs has a a as a value in the column, no reason that a dog can have a name called (a)
# * columns like in reply to user id and in reply to status id has many null objects so need to drop these columns
# * drop the columns of the retweeted status id as we are interested in the original tweets not the retweeted
# * there are values where the denonmirator is zero and that can't be true as you can't divide by zero
# * the entry or the record where the column of rating denominator of 170 must be deleted
# * remove the retweeted tweets
# ## TIDNESS for df
# * there is 4 columns for one variable which is dog type ( pupper , puppo, floofer)
# * no need for the column rating_ denominator as it is always 10

# %%
#df = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# ## Changing the (a) name of the dog to None as it is the most suitable logical value that the dog could have instead of having a letter as a name

# %%
df['name'].replace('a', None, inplace=True)

# %% [markdown]
# ## Checking that we have no (a) name in our data

# %%
df[df['name']=='a']
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### it is clear that e succeeded and we have no a dog name with *a* as a name

# %% [markdown]
# ## changing the timestamp to type datetime and make sure that no date beyond 1 august 2017

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df['timestamp'] = df['timestamp'].str.slice(0,10)

# %% [markdown]
# ## Checking that we sliced correctly the hours and only left the date related to day,month and year

# %%
df.head(10)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id   timestamp  \
# 0  892420643555336193                    NaN                  NaN  2017-08-01
# 1  892177421306343426                    NaN                  NaN  2017-08-01
# 2  891815181378084864                    NaN                  NaN  2017-07-31
# 3  891689557279858688                    NaN                  NaN  2017-07-30
# 4  891327558926688256                    NaN                  NaN  2017-07-29
# 5  891087950875897856                    NaN                  NaN  2017-07-29
# 6  890971913173991426                    NaN                  NaN  2017-07-28
# 7  890729181411237888                    NaN                  NaN  2017-07-28
# 8  890609185150312448                    NaN                  NaN  2017-07-27
# 9  890240255349198849                    NaN                  NaN  2017-07-26
#
#                                                                                source  \
# ...

# %% [markdown]
# > converting the column to the timestamp and query the dates to be not beyond 1 august 2017

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'],format='%Y-%m-%d')

# %%
df = df.query("timestamp <= '2017-08-01'")

# %% [markdown]
# ## Testing that we succeeded in changing the type and filtering the date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  timestamp  \
# 0  892420643555336193                    NaN                  NaN 2017-08-01
# 1  892177421306343426                    NaN                  NaN 2017-08-01
# 2  891815181378084864                    NaN                  NaN 2017-07-31
# 3  891689557279858688                    NaN                  NaN 2017-07-30
# 4  891327558926688256                    NaN                  NaN 2017-07-29
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# ## Combining the one variable that is in 4 columns into one column called type as they are the same variable

# %%
df['doggo'].unique()
# Out:
# array(['None', 'doggo'], dtype=object)

# %%
#for x in df['doggo']:
 #   print(x)

# %%
#for x in df['doggo']:
 #   if x == 'None':
  #      x == np.nan

# %%
df['doggo'].replace('None', np.nan, inplace=True)
df['floofer'].replace('None', np.nan, inplace=True)
df['pupper'].replace('None', np.nan, inplace=True)
df['puppo'].replace('None', np.nan, inplace=True)

# %%
df['doggo'].dropna(inplace=True)
df['floofer'].dropna(inplace=True)
df['pupper'].dropna(inplace=True)
df['puppo'].dropna(inplace=True)

# %%
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  timestamp  \
# 0  892420643555336193                    NaN                  NaN 2017-08-01
# 1  892177421306343426                    NaN                  NaN 2017-08-01
# 2  891815181378084864                    NaN                  NaN 2017-07-31
# 3  891689557279858688                    NaN                  NaN 2017-07-30
# 4  891327558926688256                    NaN                  NaN 2017-07-29
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         97 non-null object
# floofer                       10 non-null object
# pupper                        257 non-null object
# ...

# %%
df['Type'] = df[df.columns[13:]].apply(
    lambda x: ','.join(x.astype(str)),
    axis=1)

# %%
#df = df.replace(to_replace='None', value=np.nan).dropna()

# %%
df.tail(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#       timestamp  \
# 2351 2015-11-16
# 2352 2015-11-16
# 2353 2015-11-15
# 2354 2015-11-15
# 2355 2015-11-15
#
#                                                                                   source  \
# 2351  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2352  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2353  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
df['Type'].value_counts()
# Out:
# nan,nan,nan,nan          1976
# nan,nan,pupper,nan        245
# doggo,nan,nan,nan          83
# nan,nan,nan,puppo          29
# doggo,nan,pupper,nan       12
# nan,floofer,nan,nan         9
# doggo,floofer,nan,nan       1
# doggo,nan,nan,puppo         1
# Name: Type, dtype: int64

# %%
df['Type'].dropna(inplace=True)

# %%
df['Type'].value_counts()
# Out:
# nan,nan,nan,nan          1976
# nan,nan,pupper,nan        245
# doggo,nan,nan,nan          83
# nan,nan,nan,puppo          29
# doggo,nan,pupper,nan       12
# nan,floofer,nan,nan         9
# doggo,floofer,nan,nan       1
# doggo,nan,nan,puppo         1
# Name: Type, dtype: int64

# %%
df['Type'].replace('nan,nan,nan,nan', np.nan, inplace=True)
df['Type'].replace('nan,nan,pupper,nan','pupper', inplace=True)
df['Type'].replace('doggo,nan,nan,nan', 'doggo', inplace=True)
df['Type'].replace('nan,nan,nan,puppo', 'puppo', inplace=True)
df['Type'].replace('nan,floofer,nan,nan', 'floofer', inplace=True)
#df['Type'].replace('nan,nan,nan,nan', np.nan, inplace=True)
#df['Type'].replace('nan,nan,nan,nan', np.nan, inplace=True)

# %%
df['Type'].value_counts()
# Out:
# pupper                   245
# doggo                     83
# puppo                     29
# doggo,nan,pupper,nan      12
# floofer                    9
# doggo,floofer,nan,nan      1
# doggo,nan,nan,puppo        1
# Name: Type, dtype: int64

# %%
df[df['Type']=='doggo,floofer,nan,nan'].text
# Out:
# 200    At first I thought this was a shy doggo, but it's actually a Rare Canadian Floofer Owl. Amateurs would confuse the two. 11/10 only send dogs https://t.co/TXdT3tmuYk
# Name: text, dtype: object

# %% [markdown]
# >by examining the text above assoicated with the tweet we see it is a floofer so we will correct it

# %%
df['Type'].replace('doggo,floofer,nan,nan', 'floofer', inplace=True)

# %%
df[df['Type']=='doggo,nan,nan,puppo'].text
# Out:
# 191    Here's a puppo participating in the #ScienceMarch. Cleverly disguising her own doggo agenda. 13/10 would keep the planet habitable for https://t.co/cMhq16isel
# Name: text, dtype: object

# %%
df['Type'].replace('doggo,nan,nan,puppo', 'doggo', inplace=True)

# %%
df[df['Type']=='doggo,nan,pupper,nan'].text
# Out:
# 460     This is Dido. She's playing the lead role in "Pupper Stops to Catch Snow Before Resuming Shadow Box with Dried Apple." 13/10 (IG: didodoggo) https://t.co/m7isZrOBX7
# 531                         Here we have Burke (pupper) and Dexter (doggo). Pupper wants to be exactly like doggo. Both 12/10 would pet at same time https://t.co/ANBpEYHaho
# 565                                                                                                    Like doggo, like pupper version 2. Both 11/10 https://t.co/9IxWAXFqze
# 575                         This is Bones. He's being haunted by another doggo of roughly the same size. 12/10 deep breaths pupper everything's fine https://t.co/55Dqe0SJNj
# 705     This is Pinot. He's a sophisticated doggo. You can tell by the hat. Also pointier than your average pupper. Still 10/10 would pet cautiously https://t.co/f2wmLZTPHd
# ...

# %%
df['Type'].replace('doggo,nan,pupper,nan', 'doggo,pupper', inplace=True)

# %% [markdown]
# ## programming checking our new column ( type) to see the counts in it

# %%
df['Type'].value_counts()
# Out:
# pupper          245
# doggo            84
# puppo            29
# doggo,pupper     12
# floofer          10
# Name: Type, dtype: int64

# %% [markdown]
# ## visual checking for our dataframe

# %%
df.head(5)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  timestamp  \
# 0  892420643555336193                    NaN                  NaN 2017-08-01
# 1  892177421306343426                    NaN                  NaN 2017-08-01
# 2  891815181378084864                    NaN                  NaN 2017-07-31
# 3  891689557279858688                    NaN                  NaN 2017-07-30
# 4  891327558926688256                    NaN                  NaN 2017-07-29
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         97 non-null object
# floofer                       10 non-null object
# pupper                        257 non-null object
# ...

# %% [markdown]
# ## we now should drop the doggo,floofer,pupper,puppo columns

# %%
df.drop(columns=['doggo','floofer','pupper','puppo'],inplace=True)

# %% [markdown]
# ## checking that we dropped the columns and combined them in one column called Type

# %%
df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  timestamp  \
# 0  892420643555336193                    NaN                  NaN 2017-08-01
# 1  892177421306343426                    NaN                  NaN 2017-08-01
# 2  891815181378084864                    NaN                  NaN 2017-07-31
# 3  891689557279858688                    NaN                  NaN 2017-07-30
# 4  891327558926688256                    NaN                  NaN 2017-07-29
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# ## Dropping the unimportant columns inreply to status id , in reply to user id , retweeted status timestamp , rating denominator

# %%
df.drop(columns=['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_timestamp','rating_denominator'],inplace=True)

# %%
df.head()
# Out:
#              tweet_id  timestamp  \
# 0  892420643555336193 2017-08-01
# 1  892177421306343426 2017-08-01
# 2  891815181378084864 2017-07-31
# 3  891689557279858688 2017-07-30
# 4  891327558926688256 2017-07-29
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                  text  \
# ...

# %% [markdown]
# ## programming checking our dataframe right now

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 10 columns):
# tweet_id                    2356 non-null int64
# timestamp                   2356 non-null datetime64[ns]
# source                      2356 non-null object
# text                        2356 non-null object
# retweeted_status_id         181 non-null float64
# retweeted_status_user_id    181 non-null float64
# expanded_urls               2297 non-null object
# rating_numerator            2356 non-null int64
# name                        2356 non-null object
# Type                        380 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 202.5+ KB

# %% [markdown]
# ## we now are going to know the retweeted tweets in our dataframe and remove them

# %%
#df.retweeted_status_id.unique()

# %% [markdown]
# ## querying the retweeted tweets in our data

# %%
df[df['retweeted_status_id'].isna()==False]
# Out:
#                 tweet_id  timestamp  \
# 19    888202515573088257 2017-07-21
# 32    886054160059072513 2017-07-15
# 36    885311592912609280 2017-07-13
# 68    879130579576475649 2017-06-26
# 73    878404777348136964 2017-06-24
# 74    878316110768087041 2017-06-23
# 78    877611172832227328 2017-06-21
# 91    874434818259525634 2017-06-13
# 95    873697596434513921 2017-06-11
# 97    873337748698140672 2017-06-10
# 101   872668790621863937 2017-06-08
# 109   871166179821445120 2017-06-04
# 118   869988702071779329 2017-05-31
# 124   868639477480148993 2017-05-28
# 130   867072653475098625 2017-05-23
# 132   866816280283807744 2017-05-23
# 137   866094527597207552 2017-05-21
# 146   863471782782697472 2017-05-13
# 155   861769973181624320 2017-05-09
# 159   860981674716409858 2017-05-06
# 160   860924035999428608 2017-05-06
# 165   860177593139703809 2017-05-04
# 171   858860390427611136 2017-05-01
# 180   857062103051644929 2017-04-26
# 182   856602993587888130 2017-04-24
# ...

# %% [markdown]
# ## Coding to remove the retweeted tweets

# %%
df = df[df['retweeted_status_id'].isna()==True]

# %% [markdown]
# ## checking programming if there still retweets

# %%
df[df['retweeted_status_id'].isna()==False]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, expanded_urls, rating_numerator, name, Type]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 10 columns):
# tweet_id                    2175 non-null int64
# timestamp                   2175 non-null datetime64[ns]
# source                      2175 non-null object
# text                        2175 non-null object
# retweeted_status_id         0 non-null float64
# retweeted_status_user_id    0 non-null float64
# expanded_urls               2117 non-null object
# rating_numerator            2175 non-null int64
# name                        2175 non-null object
# Type                        344 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 186.9+ KB

# %% [markdown]
# ## dropping the retweeted_status_id and the retweeted_status_user id

# %%
df.drop(columns=['retweeted_status_id','retweeted_status_user_id'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 8 columns):
# tweet_id            2175 non-null int64
# timestamp           2175 non-null datetime64[ns]
# source              2175 non-null object
# text                2175 non-null object
# expanded_urls       2117 non-null object
# rating_numerator    2175 non-null int64
# name                2175 non-null object
# Type                344 non-null object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 152.9+ KB

# %% [markdown]
# ## Cleaning the source column to clearly have an info about the real source of the data meaning extract the real source not the whole url

# %%
#df['timestamp'] = pd.to_datetime(df['timestamp'],format='%Y-%m-%d')
Source = []
for x in df['source']:
    h = x.find('rel="nofollow">')
    h1 = x[h+15:-4]
    Source.append(h1)

# %%
#df.head()
df['Source']=Source

# %% [markdown]
# ## Testing
# > checking the code we did to see the column Source we need

# %%
#import datetime
#datetime.datetime.strptime
df.head()
# Out:
#              tweet_id  timestamp  \
# 0  892420643555336193 2017-08-01
# 1  892177421306343426 2017-08-01
# 2  891815181378084864 2017-07-31
# 3  891689557279858688 2017-07-30
# 4  891327558926688256 2017-07-29
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                                  text  \
# ...

# %%
#df['timestamp'] =df[df['timestamp'] < pd.Timestamp(2017,8,1)]
df.Source.unique()
# Out:
# array(['Twitter for iPhone', 'Twitter Web Client', 'Vine - Make a Scene',
#        'TweetDeck'], dtype=object)

# %% [markdown]
# ## we need to drop the old source column so we have only one source column containing the useful info

# %%
#df['timestamp'] =df[df['timestamp'] < "2017-08-01"]
df.drop(columns=['source'],inplace=True)

# %%
#df.info()
df.head()
# Out:
#              tweet_id  timestamp  \
# 0  892420643555336193 2017-08-01
# 1  892177421306343426 2017-08-01
# 2  891815181378084864 2017-07-31
# 3  891689557279858688 2017-07-30
# 4  891327558926688256 2017-07-29
#
#                                                                                                                                                                  text  \
# 0                                                       This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# 1  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
# 2                   This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 8 columns):
# tweet_id            2175 non-null int64
# timestamp           2175 non-null datetime64[ns]
# text                2175 non-null object
# expanded_urls       2117 non-null object
# rating_numerator    2175 non-null int64
# name                2175 non-null object
# Type                344 non-null object
# Source              2175 non-null object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 152.9+ KB

# %% [markdown]
# ## Working with df2

# %% [markdown]
# ## Quality for df2
# * not all the image predicitions are for dogs p1 dogs,p2 dogs , p3 dogs must one of them true ( we need to be sure that one of the 3 columns containing true, if there is a label where all these values not true that means the photo isn't for a dog
# * there is no column to take decision saying that the most probable is the photo is a type of that dog
# * total column is ambiguous why it can't sum to be 1
# ### Tidness for df2
# * the jpg_url isn't the same url as the expanded url in df1, one opens the photo of the dog and thee other opens the photo of the dog giving the status and the tweet in twitter
# * need to remove the entries or records that doesn't contain a photo of a dog according to the three algorithms

# %%
df2 = pd.read_csv('image-predictions', sep='\t')

# %%
df2_try = pd.read_csv('image-predictions', sep='\t')

# %% [markdown]
# ## Visual assessment for df2

# %%
#df.head()
df2.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# ## Programming assessment for df2

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ## cleaning the first issue as we need the data where p1 or p2 or p3 is true indicating that the photo is a dog

# %%
df2 = df2.query("p3_dog==True | p1_dog==True | p2_dog==True")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1751 entries, 0 to 2073
# Data columns (total 12 columns):
# tweet_id    1751 non-null int64
# jpg_url     1751 non-null object
# img_num     1751 non-null int64
# p1          1751 non-null object
# p1_conf     1751 non-null float64
# p1_dog      1751 non-null bool
# p2          1751 non-null object
# p2_conf     1751 non-null float64
# p2_dog      1751 non-null bool
# p3          1751 non-null object
# p3_conf     1751 non-null float64
# p3_dog      1751 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 141.9+ KB

# %% [markdown]
# ## Checking programming wise using .info method

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1751 entries, 0 to 2073
# Data columns (total 12 columns):
# tweet_id    1751 non-null int64
# jpg_url     1751 non-null object
# img_num     1751 non-null int64
# p1          1751 non-null object
# p1_conf     1751 non-null float64
# p1_dog      1751 non-null bool
# p2          1751 non-null object
# p2_conf     1751 non-null float64
# p2_dog      1751 non-null bool
# p3          1751 non-null object
# p3_conf     1751 non-null float64
# p3_dog      1751 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 141.9+ KB

# %%
df2.describe()
# Out:
#            tweet_id      img_num      p1_conf      p2_conf       p3_conf
# count  1.751000e+03  1751.000000  1751.000000  1751.000000  1.751000e+03
# mean   7.415895e+17     1.214734     0.604207     0.137715  6.161188e-02
# std    6.815223e+16     0.574337     0.265911     0.101297  5.192022e-02
# min    6.660209e+17     1.000000     0.044333     0.000010  2.160900e-07
# 25%    6.783065e+17     1.000000     0.377079     0.055020  1.608055e-02
# 50%    7.182469e+17     1.000000     0.605304     0.121811  5.000780e-02
# 75%    7.966223e+17     1.000000     0.848720     0.199439  9.480810e-02
# max    8.921774e+17     4.000000     0.999984     0.467678  2.734190e-01

# %% [markdown]
# ## trying to the see the common tweet id between df and df2
# this will help us in the cleaning process

# %% [markdown]
# > we will create a dataframe where it is sorted ascendingly depending on the tweet id

# %%
df_modify = df.sort_values(by='tweet_id',ascending=True)

# %%
##df['timestamp'] = pd.to_datetime(df['timestamp'])
i = 0
z2 = 0
for x in range(len(df2['tweet_id'])):
    if ( df2.iloc[x,0] == df_modify.iloc[x,0]  ):
        i = i+1
    else:
        z2=z2+1

# %%
print(i)
print(z2)
# Out:
# 6
# 1745

# %% [markdown]
# that means we only have 6 tweets after filtering df2 to include pictures that predicited to be a dog that are common in df and df2 , which means 6 only we can merge on them to have image predicitions

# %% [markdown]
# ## we will see the common tweets between df and df2 but without filtering df2 to see the image that said to be a dog image based on the 3 predicition algoirthms

# %%
##df['timestamp'] = pd.to_datetime(df['timestamp'])
i_try = 0
z2_try = 0
for x in range(len(df2_try['tweet_id'])):
    if ( df2_try.iloc[x,0] == df_modify.iloc[x,0]  ):
        i_try = i_try+1
    else:
        z2_try=z2_try+1

# %%
print(i_try)
print(z2_try)
# Out:
# 79
# 1996

# %% [markdown]
# now we have a different conlusion, that there are 79 common between df and df2 which means that there are 73 ( 79 - 6 ) in our df dataframe containing tweets that have photos of something not dogs

# %% [markdown]
# that can gives us an indication that joining these dataframes won't be useful as we think

# %%
pd.options.display.max_colwidth = 300

# %%
df['expanded_urls'].head()
# Out:
# 0                                                                    https://twitter.com/dog_rates/status/892420643555336193/photo/1
# 1                                                                    https://twitter.com/dog_rates/status/892177421306343426/photo/1
# 2                                                                    https://twitter.com/dog_rates/status/891815181378084864/photo/1
# 3                                                                    https://twitter.com/dog_rates/status/891689557279858688/photo/1
# 4    https://twitter.com/dog_rates/status/891327558926688256/photo/1,https://twitter.com/dog_rates/status/891327558926688256/photo/1
# Name: expanded_urls, dtype: object

# %%
df2['jpg_url'].head()
# Out:
# 0    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# Name: jpg_url, dtype: object

# %% [markdown]
# ## we can see that there is a difference between the two urls of the df and df2, that is a tidness problem, which one should we use or we leave them as they are ?
# I will go with leaving them alone as I will not join these dataframes

# %% [markdown]
# ## start with df3

# %% [markdown]
# ## quality for df3
# * contributors column is all null
# * coordinates column is all null
# * place column contain only 1 non null so it isn't necessary
# * user column isnt adding any info as it is the same user
# * source column won't also add any extra info need to extract the source from it
# * no need for lang column as this obvious it is an english account
# ## tidness for df3
# * full text column dropped as we are going to join this dataframe with df1
# * columns sensitive and sensitive appeale ar false and nans so they should be deleted so no useful info
# * created at need to change to datetime type not object
# * display text range column need to be removed
# * entites column need to be removed
# * extended_entities column need to be removed
# * geo column isn't necessary
# * change the name of column (id) to (tweet_id) so that we have the same name of column for the same variable
# * change the typr of created at to be datetime type

# %%
with open('tweet_json.txt') as file:
    status = []
    for line in file:
        status.append(json.loads(line))

# %%
df3= pd.DataFrame.from_records(status)

# %%
df3.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'favorite_count', 'favorited',
#        'full_text', 'geo', 'id', 'id_str', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status',
#        'lang', 'place', 'possibly_sensitive', 'possibly_sensitive_appealable',
#        'quoted_status', 'quoted_status_id', 'quoted_status_id_str',
#        'quoted_status_permalink', 'retweet_count', 'retweeted',
#        'retweeted_status', 'source', 'truncated', 'user'],
#       dtype='object')

# %% [markdown]
# ## drop the unimportant columns ( contributors,coordinates,user,place,geo,truncated,entites,extended_entities)
# also drop id_str as we have th column called id so no need to have same nfo but as string

# %%
#df3.drop(columns=['contributors','coordinates','geo','place','lang','truncated','id_str','entities','extended_entities'])

# %% [markdown]
# ## change the source column as we did in df1 so that we extract the important ssource only then remove the original source column from our dataframe

# %%
Source = []
for x in df3['source']:
    h = x.find('rel="nofollow">')
    h1 = x[h+15:-4]
    Source.append(h1)

# %%
df3['Source']=Source

# %%
#df3.drop(columns=['contributors','coordinates','geo','place','lang','truncated','id_str','entities','extended_entities','source'])

# %%
df3.head()
# Out:
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Tue Aug 01 16:23:56 +0000 2017            [0, 85]
# 1         None        None  Tue Aug 01 00:17:27 +0000 2017           [0, 138]
# 2         None        None  Mon Jul 31 00:18:03 +0000 2017           [0, 121]
# 3         None        None  Sun Jul 30 15:58:51 +0000 2017            [0, 79]
# 4         None        None  Sat Jul 29 16:00:24 +0000 2017           [0, 138]
#
#                                                                                                                                                                                                                                                                                                       entities  \
# ...

# %% [markdown]
# ## Changing the name of Id column to tweet_id to keep the consistency among our data

# %%
df3['tweet_id'] = df3['id']

# %%
#df3.drop(columns=['user','contributors','coordinates','geo','place','lang','truncated','id_str','entities','extended_entities','source','id'])

# %% [markdown]
# ## Dropping the following colums after checking that retweeted tweets are false in all of them in_reply_to_screen_name, in_reply_to_status_id, in_reply_to_status_id_str possibly_sensitive, possibly_sensitive_appealable,display_text_range

# %%
df3.retweeted.unique()
# Out:
# array([False], dtype=bool)

# %%
#df3.drop(columns=['user','contributors','coordinates','geo','place','lang','truncated','id_str','entities','extended_entities','source','id','in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str','possibly_sensitive', 'possibly_sensitive_appealable','display_text_range','in_reply_to_user_id','in_reply_to_user_id_str','retweeted'])

# %% [markdown]
# ## Checking for the favorited column to see its values and see if it is useful to drop them

# %%
df3.favorited.unique()
# Out:
# array([False], dtype=bool)

# %% [markdown]
# ## since this column has only false values so it will be cleaner if we drop this column

# %%
#df3.drop(columns=['user','contributors','coordinates','geo','place','lang','truncated','id_str','entities','extended_entities','source','id','in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str','possibly_sensitive', 'possibly_sensitive_appealable','display_text_range','in_reply_to_user_id','in_reply_to_user_id_str','retweeted','favorited'])

# %% [markdown]
# ## we need to drop the tweets where is the is_quote_status is true because it indicats it s not a tweet, here we are interested in tweets

# %% [markdown]
# ## checking the values to know if there is a true in the column in (is_quote_status)

# %%
df3.is_quote_status.unique()
# Out:
# array([False,  True], dtype=bool)

# %%
df3[df3['is_quote_status']==True].head()
# Out:
#    contributors coordinates                      created_at  \
# 31         None        None  Sat Jul 15 02:45:48 +0000 2017
# 34         None        None  Thu Jul 13 15:19:09 +0000 2017
# 41         None        None  Mon Jul 10 03:08:17 +0000 2017
# 71         None        None  Sat Jun 24 13:24:20 +0000 2017
# 82         None        None  Sun Jun 18 20:30:39 +0000 2017
#
#    display_text_range  \
# 31            [0, 50]
# 34            [0, 47]
# 41           [0, 104]
# 71            [0, 45]
# 82           [0, 117]
#
#                                                                                                                                                                                                                                                                                                        entities  \
# ...

# %%
df3 = df3.query("is_quote_status == False")

# %% [markdown]
# ## Testing that we dropped them all so we keep only tweets

# %%
df3[df3['is_quote_status']==True]
# Out:
# Empty DataFrame
# Columns: [contributors, coordinates, created_at, display_text_range, entities, extended_entities, favorite_count, favorited, full_text, geo, id, id_str, in_reply_to_screen_name, in_reply_to_status_id, in_reply_to_status_id_str, in_reply_to_user_id, in_reply_to_user_id_str, is_quote_status, lang, place, possibly_sensitive, possibly_sensitive_appealable, quoted_status, quoted_status_id, quoted_status_id_str, quoted_status_permalink, retweet_count, retweeted, retweeted_status, source, truncated, user, Source, tweet_id]
# Index: []
#
# [0 rows x 34 columns]

# %%
df3.drop(columns=['user','contributors','coordinates','geo','place','lang','truncated','id_str','entities','extended_entities','source','id','in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str','possibly_sensitive', 'possibly_sensitive_appealable','display_text_range','in_reply_to_user_id','in_reply_to_user_id_str','retweeted','favorited'],inplace=True)

# %% [markdown]
# ## Checking retweeted_status column also

# %%
df3['retweeted_status'].sample(20)
# Out:
# 928     NaN
# 1245    NaN
# 2028    NaN
# 1596    NaN
# 2169    NaN
# 1181    NaN
# 855     NaN
# 2285    NaN
# 756     NaN
# 681     NaN
# 690     NaN
# 1958    NaN
# 1321    NaN
# 2021    NaN
# 1172    NaN
# 1307    NaN
# 1711    NaN
# 973     NaN
# 2283    NaN
# 980     NaN
# Name: retweeted_status, dtype: object

# %% [markdown]
# ## we must drop also where the column of ( retweeted_status isn't Nan)

# %%
df3[df3['retweeted_status'].isnull()==False].shape
# Out:
# (161, 12)

# %% [markdown]
# that mean that we had 161 that can be treated as retweets not original tweet so we need to remove them

# %% [markdown]
# ## CODE

# %%
df3 = df3[df3['retweeted_status'].isnull()==True]

# %% [markdown]
# ## test

# %%
df3[df3['retweeted_status'].isnull()==False]
# Out:
# Empty DataFrame
# Columns: [created_at, favorite_count, full_text, is_quote_status, quoted_status, quoted_status_id, quoted_status_id_str, quoted_status_permalink, retweet_count, retweeted_status, Source, tweet_id]
# Index: []

# %%
#df3.drop(columns=['user','contributors','coordinates','geo','place','lang','truncated','id_str','entities','extended_entities','source','id','in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str','possibly_sensitive', 'possibly_sensitive_appealable','display_text_range','in_reply_to_user_id','in_reply_to_user_id_str','retweeted','favorited'],inplace=True)

# %% [markdown]
# ## also we will drop quoted_status,quoted_status_id ,quoted_status_id_str,            quoted_status_permalink   ,is_quote_status)

# %%
df3.drop(columns=['quoted_status','quoted_status_id','is_quote_status' ,'quoted_status_id_str','quoted_status_permalink','retweeted_status'],inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2139 entries, 0 to 2330
# Data columns (total 6 columns):
# created_at        2139 non-null object
# favorite_count    2139 non-null int64
# full_text         2139 non-null object
# retweet_count     2139 non-null int64
# Source            2139 non-null object
# tweet_id          2139 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 117.0+ KB

# %% [markdown]
# ## changing the type of (created at) column to be datetime instead of object

# %%
df3['created_aat']= df3['created_at'].str.slice(start = 25, stop=30)

# %%
df3['created_aaat'] = (df3['created_at'].str.slice(4,10))

# %%
df3['created_'] = df3['created_aaat'] +df3['created_aat']

# %%
df3['timestamp'] = pd.to_datetime(df3['created_'],format='%b %d %Y')

# %%
df3 = df3.query("timestamp < '2017-08-01'")

# %% [markdown]
# ## Visual test to be sure from the format

# %%
df3.head(3)
# Out:
#                        created_at  favorite_count  \
# 2  Mon Jul 31 00:18:03 +0000 2017           22806
# 3  Sun Jul 30 15:58:51 +0000 2017           38313
# 4  Sat Jul 29 16:00:24 +0000 2017           36583
#
#                                                                                                                                                             full_text  \
# 2                   This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# 3                                                             This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us https://t.co/tD36da7qLQ
# 4  This is Franklin. He would like you to stop calling him "cute." He is a very fierce shark and should be respected as such. 12/10 #BarkWeek https://t.co/AtUZn91f7f
#
#    retweet_count              Source            tweet_id created_aat  \
# ...

# %% [markdown]
# ## checking programming way with the type of the timestamp

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2137 entries, 2 to 2330
# Data columns (total 10 columns):
# created_at        2137 non-null object
# favorite_count    2137 non-null int64
# full_text         2137 non-null object
# retweet_count     2137 non-null int64
# Source            2137 non-null object
# tweet_id          2137 non-null int64
# created_aat       2137 non-null object
# created_aaat      2137 non-null object
# created_          2137 non-null object
# timestamp         2137 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 183.6+ KB

# %% [markdown]
# ## Drop the old columns ( created_at ) and the columns we used as id stage before creating timestamp (created_aat,created_aaat ,created_ ,)

# %%
df3.drop(columns=['created_aat','created_aaat','created_','created_at'],inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ## Checking that we dropped the un needed columns

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2137 entries, 2 to 2330
# Data columns (total 6 columns):
# favorite_count    2137 non-null int64
# full_text         2137 non-null object
# retweet_count     2137 non-null int64
# Source            2137 non-null object
# tweet_id          2137 non-null int64
# timestamp         2137 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 116.9+ KB

# %%
df3.head()
# Out:
#    favorite_count  \
# 2           22806
# 3           38313
# 4           36583
# 5           18451
# 6           10736
#
#                                                                                                                                                                 full_text  \
# 2                       This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# 3                                                                 This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us https://t.co/tD36da7qLQ
# 4      This is Franklin. He would like you to stop calling him "cute." He is a very fierce shark and should be respected as such. 12/10 #BarkWeek https://t.co/AtUZn91f7f
# 5      Here we have a majestic great white breaching off South Africa's coast. Absolutely h*ckin breathtaking. 13/10 (IG: tucker_marlo) #BarkWeek https://t.co/kQ04fDDRmh
# ...

# %%
#df3 = df3.reindex(columns=['tweet_id','favorite_count',1,2,3,4,5])

# %% [markdown]
# ## Changing the order of the columns so that it is suitable according to the useful information

# %%
df3 = df3.reindex(columns=['tweet_id','timestamp','favorite_count','retweet_count','Source','full_text'])

# %% [markdown]
# ## Checking the df3 order  and columns

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2137 entries, 2 to 2330
# Data columns (total 6 columns):
# tweet_id          2137 non-null int64
# timestamp         2137 non-null datetime64[ns]
# favorite_count    2137 non-null int64
# retweet_count     2137 non-null int64
# Source            2137 non-null object
# full_text         2137 non-null object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 116.9+ KB

# %%
df3.head()
# Out:
#              tweet_id  timestamp  favorite_count  retweet_count  \
# 2  891815181378084864 2017-07-31           22806           3630
# 3  891689557279858688 2017-07-30           38313           7543
# 4  891327558926688256 2017-07-29           36583           8132
# 5  891087950875897856 2017-07-29           18451           2724
# 6  890971913173991426 2017-07-28           10736           1762
#
#                Source  \
# 2  Twitter for iPhone
# 3  Twitter for iPhone
# 4  Twitter for iPhone
# 5  Twitter for iPhone
# 6  Twitter for iPhone
#
#                                                                                                                                                                 full_text
# 2                       This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# ...

# %% [markdown]
# ## we need to remove the full text column as it is in df already no need to be in df3

# %%
df3.drop(columns = ['full_text'],inplace= True)

# %%
df3.head()
# Out:
#              tweet_id  timestamp  favorite_count  retweet_count  \
# 2  891815181378084864 2017-07-31           22806           3630
# 3  891689557279858688 2017-07-30           38313           7543
# 4  891327558926688256 2017-07-29           36583           8132
# 5  891087950875897856 2017-07-29           18451           2724
# 6  890971913173991426 2017-07-28           10736           1762
#
#                Source
# 2  Twitter for iPhone
# 3  Twitter for iPhone
# 4  Twitter for iPhone
# 5  Twitter for iPhone
# 6  Twitter for iPhone

# %%
df.head()
# Out:
#              tweet_id  timestamp  \
# 0  892420643555336193 2017-08-01
# 1  892177421306343426 2017-08-01
# 2  891815181378084864 2017-07-31
# 3  891689557279858688 2017-07-30
# 4  891327558926688256 2017-07-29
#
#                                                                                                                                                                  text  \
# 0                                                       This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# 1  This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
# 2                   This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# ...

# %%
df2.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# ## Now we need to join the suitable dataframes and then save them in a csv

# %%
df_tot= pd.merge(df,df3,how='inner')

# %%
df.shape
# Out:
# (2175, 8)

# %%
df3.shape
# Out:
# (2137, 5)

# %%
df_tot.shape
# Out:
# (2137, 10)

# %%
df_tot.head()
# Out:
#              tweet_id  timestamp  \
# 0  891815181378084864 2017-07-31
# 1  891689557279858688 2017-07-30
# 2  891327558926688256 2017-07-29
# 3  891087950875897856 2017-07-29
# 4  890971913173991426 2017-07-28
#
#                                                                                                                                                                      text  \
# 0                       This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# 1                                                                 This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us https://t.co/tD36da7qLQ
# 2      This is Franklin. He would like you to stop calling him "cute." He is a very fierce shark and should be respected as such. 12/10 #BarkWeek https://t.co/AtUZn91f7f
# ...

# %% [markdown]
# ## re arrange the columns so the important ones comes first

# %%
df_tot= df_tot.reindex(columns=['tweet_id','timestamp','favorite_count','retweet_count','rating_numerator','name','Type','Source','text','expanded_urls'])

# %% [markdown]
# ## Saving the data step

# %% [markdown]
# ## Saving the two combined and modified dataframes to a csv file called combined_data

# %%
df_tot.to_csv('Combined_data.csv',index=False)

# %% [markdown]
# ## Saving the enhanced modified dataframe df2 to a csv file called image_pred

# %%
df2.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
df2.to_csv('Image_pred.csv',index=False)

# %% [markdown]
# ## Trying to visualize and make insights

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df_tot.head()
# Out:
#              tweet_id  timestamp  favorite_count  retweet_count  \
# 0  891815181378084864 2017-07-31           22806           3630
# 1  891689557279858688 2017-07-30           38313           7543
# 2  891327558926688256 2017-07-29           36583           8132
# 3  891087950875897856 2017-07-29           18451           2724
# 4  890971913173991426 2017-07-28           10736           1762
#
#    rating_numerator      name Type              Source  \
# 0                12    Archie  NaN  Twitter for iPhone
# 1                13     Darla  NaN  Twitter for iPhone
# 2                12  Franklin  NaN  Twitter for iPhone
# 3                13      None  NaN  Twitter for iPhone
# 4                13       Jax  NaN  Twitter for iPhone
#
#                                                                                                                                                                      text  \
# ...

# %% [markdown]
# ## 1) Visualizing the ratings distribution

# %%
bins = np.arange(0,20,1)
plt.title('distribution of ratings')
plt.hist(bins=bins,x=df_tot['rating_numerator']);

# %% [markdown]
# it is clear that the rating is left skewed which means more people tends to give ratings more than 10 and that kind for rating dogs

# %% [markdown]
# ##  2) Visualizing the source of the tweets

# %%
plt.figure(figsize=(10,5))

sb.countplot(x= Source , data = df_tot)
plt.title('source of tweets');

# %% [markdown]
# it is clear that a majority almost all the tweets are done with twitter

# %% [markdown]
# ## Insights for the maximum, minimum for favorited and retweeted

# %%
df_tot.favorite_count.max()
# Out:
# 150651

# %%
df_tot.favorite_count.min()
# Out:
# 49

# %%
df_tot.retweet_count.max()
# Out:
# 74352

# %%
df_tot.retweet_count.min()
# Out:
# 1

# %% [markdown]
# ## Insights 1) does max favorite count is the same for max retweet?

# %%
df_tot[df_tot['favorite_count']==150651]
# Out:
#                tweet_id  timestamp  favorite_count  retweet_count  \
# 830  744234799360020481 2016-06-18          150651          74352
#
#      rating_numerator  name   Type              Source  \
# 830                13  None  doggo  Twitter for iPhone
#
#                                                                                                                     text  \
# 830  Here's a doggo realizing you can stand in a pool. 13/10 enlightened af (vid by Tina Conrad) https://t.co/7wE9LTEXC4
#
#                                                        expanded_urls
# 830  https://twitter.com/dog_rates/status/744234799360020481/video/1

# %% [markdown]
# >here we have that the maximum favorite has the maximum retweet

# %% [markdown]
# ## Insights 2) does min retweet count is the same for min retweet?

# %%
df_tot[df_tot['retweet_count']==1]
# Out:
#                tweet_id  timestamp  favorite_count  retweet_count  \
# 229  838085839343206401 2017-03-04             136              1
#
#      rating_numerator  name Type              Source  \
# 229                15  None  NaN  Twitter for iPhone
#
#                                                                 text  \
# 229  @bragg6of8 @Andy_Pace_ we are still looking for the first 15/10
#
#     expanded_urls
# 229           NaN

# %% [markdown]
# >the answer is no

# %% [markdown]
# ## Insights 3) does min retweet count means less rate than max retweet count?

# %%
(df_tot[df_tot['retweet_count']==1].rating_numerator.values) < (df_tot[df_tot['favorite_count']==150651].rating_numerator.values)
# Out:
# array([False], dtype=bool)

# %% [markdown]
# ## the answer is unexpected, the least and minimum retweet photo or tweet took a *higher* rate than the most and maximum retweet tweets
